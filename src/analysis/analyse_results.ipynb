# %%
# %matplotlib inline
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from utils.viz_utils import *

# %% [markdown]
# # baseline

# %% [markdown]
# ## training

# %%
fn = '../output/baseline_hierarchical/training/baseline_hierarchical_metrics.pt'
show_detailed_training_results(fn)
show_training_losses(fn, hierarchical = True)
# Out:
# seg_1
# ['OF', 'CF', 'SF']
# seg_2
# ['NF', 'F']
# seg
# ['NF', 'OF', 'CF', 'SF']
# {'input_sources': ['SI2017', 'ALTI'], 'target_source': 'TLM5c', 'output_dir': '/home/tanguyen/Documents/Projects/2020/ForestMapping/Code/ForestMapping/output/baseline_hierarchical', 'batch_size': 16, 'num_epochs': 6, 'lr': [1e-05, 1e-06, 1e-06, 1e-07], 'learning_schedule': [5, 5, 5, 5], 'n_negative_samples': [0, 5, 10, 20, 40, 80, 160, 320, 320, 320], 'negative_sampling_schedule': [2, 2, 2, 2, 2, 2, 2, 2, 2, 2], 'num_workers': 2, 'skip_validation': False, 'undersample_validation': 1, 'resume_training': False, 'no_user_input': False, 'debug': False, 'adapt_loss_weights': False, 'weight_bin_segmentation': False, 'use_subset': True, 'decision': 'h', 'lambda_bin': 1.0}

# %% [markdown]
# ## inference

# %% [markdown]
# ### train

# %%
fn = '../output/bb_hierarchical/inference/epoch_19/train/bb_hierarchical_metrics.pt'
show_model_metrics(fn, None)

# %% [markdown]
# ### validation

# %%
fn = '../output/baseline_hierarchical/training/baseline_hierarchical_metrics.pt'
show_model_metrics(fn, -1)
# Out:
# Validation results (epoch -1)
# seg
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.86      0.94      0.87      0.90     68.28 199709872
#
#      OF       0.93      0.10      0.34      0.16      1.59   4664439
#
#      CF       0.85      0.87      0.61      0.72     27.46  80315156
#
#      SF       0.86      0.10      0.48      0.17      2.66   7786979
#
#    mean       0.88      0.50      0.58      0.49    100.00 292476446
#
# overall       0.86      0.89      0.78      0.82    100.00 292476446
#
#
# seg_2
#           accuracy precision    recall  f1-score support (%)   support
#
#      NF       0.87      0.94      0.87      0.90     68.16 199709872
#
#       F       0.87      0.76      0.88      0.81     31.84  93290128
#
#    mean       0.87      0.85      0.88      0.86    100.00 293000000
#
# overall       0.87      0.88      0.87      0.87    100.00 293000000
#
#
# seg_1
# ...

# %% [markdown]
# ### test

# %%
fn = '../output/baseline_hierarchical/inference/epoch_19/test_subset/baseline_hierarchical_metrics.pt'
show_model_metrics(fn, None)
